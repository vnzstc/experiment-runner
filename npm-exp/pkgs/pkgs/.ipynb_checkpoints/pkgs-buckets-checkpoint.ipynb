# %% [markdown]
# # README
#
# In this notebook:
# - We check whether the directories contain the same number of packages and same content.
# - Define the buckets that will serve as groups in our experiments. We are not comparing packages with different sizes, thus size it is a blocking factor.

# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path
from pathlib import PosixPath

# %%
#algos = [
#    'gzip', 'xz', 'zstd', 'brotli', 'zopfli', 'tar'
#]
# (Folders, Extension)
EXTENSIONS = {
    'npm' : '.tgz',
    'xz'  : '.tar.xz'
}

# %%
def return_dir_files(dirname : str):
    '''
    Returns all the files from a specified @dirpath 
    and collects all the files with the expected extension. 
    '''
    if dirname not in EXTENSIONS:
        raise KeyError(f"no extension configured for {dirname!r}")
    target_extension = EXTENSIONS[dirname]
    
    dirpath = Path(dirname)
    if not dirpath.is_dir():
        raise FileNotFoundError(f"directory {dirpath} not found")
    # collects files with expected extension
    return [
        filepath for filepath in dirpath.iterdir()
        if filepath.is_file() and filepath.name.endswith(target_extension)
    ]

# %%
def true_stem(p: Path) -> str:
    name = p.name
    for ext in list(EXTENSIONS.values()):
        if name.endswith(ext):
            return name[: -len(ext)]
    return p.stem

# %%
def get_intersection(array : list[list[Path]]):
    '''returns elements in common in list of list of paths'''
    sets = [set(map(lambda p: true_stem(p), l)) for l in array]
    return list(set.intersection(*sets))

# %%
def get_sizes(files : list[Path]): 
    return [
        {'name': f, 'size' : f.stat().st_size} for f in files
    ]

# %%
allfiles = {
    key : return_dir_files(key) for key in EXTENSIONS
}

sizes = {
    key : pd.DataFrame(get_sizes(allfiles[key])) for key in allfiles
}

# list of strings
intersection = get_intersection(list(allfiles.values()))

# %%
# same packages across populations
for k in sizes:
    sizes[k]['_key'] = sizes[k]['name'].apply(true_stem)
    sizes[k] = sizes[k][sizes[k]['_key'].isin(intersection)]

# %% [markdown]
# # Buckets

# %%
def analyze_size_buckets(df, n_buckets=120):
    df = df.copy()
    df['log_size'] = np.log10(df['size'])
    df['bucket'] = pd.qcut(df['log_size'], q=n_buckets, labels=False, duplicates='drop')
    grp = df.groupby('bucket', observed=True)['size'].agg(['count', 'min', 'max', 'mean', 'std'])
    grp['cv'] = grp['std'] / grp['mean']
    return df, grp

# %%
# make the buckets according to the original compression
bucket_df, buckets = analyze_size_buckets(sizes['npm'])

# %%
max_value = int(max(bucket_df['bucket']))
sample = bucket_df[bucket_df['bucket'] == max_value]
sample
# Out:
#                                                    name      size  \
# 5     npm/@next__swc-darwin-arm64--swc-darwin-arm64-...  41074963
# 53    npm/@next__swc-win32-arm64-msvc--swc-win32-arm...  36351635
# 456     npm/@esbuild__win32-ia32--win32-ia32-0.28.0.tgz   4631098
# 553   npm/@next__swc-win32-ia32-msvc--swc-win32-ia32...  29615097
# 628   npm/@next__swc-darwin-x64--swc-darwin-x64-16.2...  42848882
# 715       npm/@esbuild__aix-ppc64--aix-ppc64-0.28.0.tgz   4580360
# 892                           npm/next--next-16.2.6.tgz  34117698
# 1254  npm/@next__swc-linux-arm64-gnu--swc-linux-arm6...  42467391
# 1274      npm/@esbuild__sunos-x64--sunos-x64-0.28.0.tgz   4690115
# 1324  npm/@next__swc-linux-x64-musl--swc-linux-x64-m...  45191121
# 1349  npm/@next__swc-linux-x64-gnu--swc-linux-x64-gn...  45179442
# 1370    npm/@esbuild__netbsd-x64--netbsd-x64-0.28.0.tgz   4677411
# 1552  npm/@next__swc-linux-arm64-musl--swc-linux-arm...  42194115
# 1613      npm/@esbuild__win32-x64--win32-x64-0.28.0.tgz   4805723
# 1616  npm/@esbuild__openbsd-x64--openbsd-x64-0.28.0.tgz   4684808
# 1894  npm/@next__swc-win32-x64-msvc--swc-win32-x64-m...  43693233
# 2025      npm/@esbuild__linux-x64--linux-x64-0.28.0.tgz   4717499
# 2027    npm/@esbuild__darwin-x64--darwin-x64-0.28.0.tgz   4778978
# 2264  npm/@esbuild__linux-s390x--linux-s390x-0.28.0.tgz   4542398
# 2352  npm/@esbuild__freebsd-x64--freebsd-x64-0.28.0.tgz   4690660
# 2452                  npm/aws-sdk--aws-sdk-2.1693.0.tgz  11791955
#
#                                                    _key  log_size  bucket
# 5      @next__swc-darwin-arm64--swc-darwin-arm64-16.2.6  7.613577     119
# 53    @next__swc-win32-arm64-msvc--swc-win32-arm64-m...  7.560524     119
# 456             @esbuild__win32-ia32--win32-ia32-0.28.0  6.665684     119
# 553   @next__swc-win32-ia32-msvc--swc-win32-ia32-msv...  7.471513     119
# 628        @next__swc-darwin-x64--swc-darwin-x64-16.2.6  7.631939     119
# 715               @esbuild__aix-ppc64--aix-ppc64-0.28.0  6.660900     119
# 892                                   next--next-16.2.6  7.532980     119
# 1254  @next__swc-linux-arm64-gnu--swc-linux-arm64-gn...  7.628056     119
# 1274              @esbuild__sunos-x64--sunos-x64-0.28.0  6.671183     119
# 1324  @next__swc-linux-x64-musl--swc-linux-x64-musl-...  7.655053     119
# 1349  @next__swc-linux-x64-gnu--swc-linux-x64-gnu-16...  7.654941     119
# 1370            @esbuild__netbsd-x64--netbsd-x64-0.28.0  6.670006     119
# 1552  @next__swc-linux-arm64-musl--swc-linux-arm64-m...  7.625252     119
# 1613              @esbuild__win32-x64--win32-x64-0.28.0  6.681759     119
# 1616          @esbuild__openbsd-x64--openbsd-x64-0.28.0  6.670692     119
# 1894  @next__swc-win32-x64-msvc--swc-win32-x64-msvc-...  7.640414     119
# 2025              @esbuild__linux-x64--linux-x64-0.28.0  6.673712     119
# 2027            @esbuild__darwin-x64--darwin-x64-0.28.0  6.679335     119
# 2264          @esbuild__linux-s390x--linux-s390x-0.28.0  6.657285     119
# 2352          @esbuild__freebsd-x64--freebsd-x64-0.28.0  6.671234     119
# 2452                          aws-sdk--aws-sdk-2.1693.0  7.071586     119

# %%
sample.to_csv("sample.csv", index=False)
